# %%
import json
import base64
import requests
import time
import jwt

# %%
# !ls /home/sven/cordra-2.2.0/userkeys
# Out:
# sven  sven.pub

# %%
with open("/home/sven/cordra-2.2.0/userkeys/sven", "rb") as f:
    privatekey = f.read()
    
with open("/home/sven/cordra-2.2.0/userkeys/sven.pub", "rb") as f:
    publickey = f.read()
    
publickey
# Out:
# b'ssh-rsa  sven@syoga\n'

# %%
jwtpayload = {
    "iss": "sven",
    "exp": round(time.time()+600)
}

encoded = jwt.encode(jwtpayload, privatekey, algorithm='RS256')

encoded
# Out:
# b'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJpc3MiOiJzdmVuIiwiZXhwIjoxNjA1ODk5OTI5fQ.hWEMi8zUpvl3M_ch5WoVMYbBqCCqy74TzPK1VT7CICedOd7vrhaD38RUUCw1LM3ygV5CsaLfqzom3xO7ueeZtvXXrSKuBsL79CYMgkUQ6acxxTCnZLFxE-IkeQ-pGB4BkfWiNhJLJzvZgnAcHJsRIEd9iGQBeMRnSChS8mqD1qNlVj6kcmUHjgpcICpqGGJ1SyoBOmHLQI3z7tlgMOEyG5WR9hfExv7iaT4C-dANk9rZHDgrK4fPpNYPxvnbhG__Bw5C-crIZkONebpNCK-0RCxq5uV7ccZtUQ-fqfr-pbUh18R--oNJZ7tkWc2tOJH_0-4r6ZyaD3m9IgysYhVjvA'

# %%
jwt.decode(encoded, publickey)
# Out:
# {'iss': 'sven', 'exp': 1605899929}

# %%
headers = {
    'Authorization': 'Bearer ' + encoded.decode('utf-8')
}

r = requests.get('https://127.0.0.1:8443/objects/?query=*', headers=headers, verify=False)

r
# Out:
# /home/sven/miniconda3/envs/mathub/lib/python3.7/site-packages/urllib3/connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# <Response [200]>

# %%
r.json()
# Out:
# {'pageNum': 0,
#  'pageSize': -1,
#  'size': 4,
#  'results': [{'id': '7.local/dd860110a62b19214c4e',
#    'type': 'User',
#    'content': {'id': '7.local/dd860110a62b19214c4e',
#     'username': 'sven',
#     'password': '',
#     'majorkey': {'kty': 'RSA',
#      'use': 'sig',
#      'n': 'AKSqTYPoOOzetcQUxLSqpRhEYHSNvZW78Ehoao4yZqukXPoi1NXMfnQX4i81O_wTNkcacw95msOmQPlqaF6JQRedUjk1eAFYhNCNXR5ZQEZXfUSOXa_bvhdk_Ek-fJPmgRne-4GTLDtEJbdtO2VSU71GMMGqJrJB5O0mx7rQMQCrZUG-zFvgcrodA84AtjV-iDGxZJazdYcqWAkERZu61puAe1jJq_OF9e_AzZnuFBU-jxUN9VV0vLBPJ1yCzneXrv_rTqyi9YR-dhxeK318rCIRrbq0Mc_MRyUUWyxaFZrfKpJlLVkFLje53qbipqatp8POmXVw_-jFoXvCIQ8cPhM',
#      'e': 'AQAB'}},
#    'metadata': {'createdOn': 1605729942762,
#     'createdBy': 'admin',
#     'modifiedOn': 1605891090072,
#     'modifiedBy': 'admin',
#     'txnId': 1605891090066013}},
#   {'id': '7.local/7ec8e6af01016f26f48b',
#    'type': 'Schema',
#    'content': {'identifier': '7.local/7ec8e6af01016f26f48b',
#     'name': 'Group',
# ...

# %%
requests.get('https://127.0.0.1:8443/objects/?query=*', verify=False).json()
# Out:
# /home/sven/miniconda3/envs/mathub/lib/python3.7/site-packages/urllib3/connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# {'pageNum': 0,
#  'pageSize': -1,
#  'size': 3,
#  'results': [{'id': '7.local/7ec8e6af01016f26f48b',
#    'type': 'Schema',
#    'content': {'identifier': '7.local/7ec8e6af01016f26f48b',
#     'name': 'Group',
#     'schema': {'type': 'object',
#      'required': ['id', 'groupName', 'description'],
#      'properties': {'id': {'type': 'string',
#        'cordra': {'type': {'autoGeneratedField': 'handle'}}},
#       'groupName': {'type': 'string',
#        'title': 'Group Name',
#        'cordra': {'preview': {'showInPreview': True, 'isPrimary': True}}},
#       'description': {'type': 'string',
#        'format': 'textarea',
# ...

# %%
class Token:
    def create(host, username, password, verify=None, full=False):
        """Create an access Token"""

        params = dict()
        params["full"] = full

        auth_json = dict()
        auth_json["grant_type"] = token_grant_type
        auth_json["username"] = username
        auth_json["password"] = password

        r = check_response(
            requests.post(
                endpoint_url(host, token_create_endpoint),
                params=params,
                data=auth_json,
                verify=verify,
            )
        )
        return r

    def read(host, token, verify=None, full=False):
        """Read an access Token"""

        params = dict()
        params["full"] = full

        auth_json = dict()
        auth_json["token"] = get_token_value(token)

        r = check_response(
            requests.post(
                endpoint_url(host, token_read_endpoint),
                params=params,
                data=auth_json,
                verify=verify,
            )
        )
        return r

    def delete(host, token, verify=None):
        """Delete an access Token"""

        auth_json = dict()
        auth_json["token"] = get_token_value(token)

        r = check_response(
            requests.post(
                endpoint_url(host, token_delete_endpoint), data=auth_json, verify=verify
            )
        )
        return r

# %%
token
# Out:
# {'access_token': '1uoi7vs3ulea97cpa4xns34b8',
#  'token_type': 'Bearer',
#  'active': True,
#  'userId': 'test/98e182d04a2a56bdd28a',
#  'username': 'svenpvoigt'}

# %%
json_files = glob.glob('*.json')

# %%
for i,json_file in enumerate(json_files):
    png_file = json_file.replace('.json','.png')
    tiff_file = json_file.replace('.json','.tiff')
    with open(json_file) as f:
        obj = json.load(f)
    
    payloads = {
        'thumbnail': (png_file, open(png_file,'rb')),
        'image': (tiff_file, open(tiff_file,'rb'))
    }
    
    my_acl = dict()
    my_acl['readers'] = ['public']
    my_acl['writers'] = ['test/b1187cc0b52c9f37e17b']
    
    response = cordrapy.Objects.create(
        host,
        obj,
        obj_type,
        handle=obj['@id'],
        token=token,
        verify=False,
        acls=my_acl,
        payloads=payloads
    )
    print(i, response)
    
    #break
# Out:
# 0 {'@context': ['http://schema.org/', {'mat': 'https://pages.nist.gov/material-schema/', 'parameterControlled': 'mat:parameterControlled'}], '@type': ['Dataset', 'mat:File'], '@id': 'test/6859965e-bcec-4838-818b-1cbfb9df6952', 'name': 'PyMKS synthetic microstructure gx-50_gy-200_va-0.2_vb-0.2', 'about': ['test/36b943eb21e64e308b75'], 'accountablePerson': ['test/7c9446eb5abf408d3d0e'], 'author': ['test/00353486eaab904d29e1', 'test/7c9446eb5abf408d3d0e'], 'license': 'https://creativecommons.org/publicdomain/zero/1.0/', 'thumbnailUrl': ['https://api.materialhub.org/objects/test/6859965e-bcec-4838-818b-1cbfb9df6952?payload=thumbnail'], 'measurementTechnique': ['test/026f90694d58ac2eee70'], 'parameterControlled': [{'@type': 'PropertyValue', 'name': 'Target Grain Size x', 'value': 50, 'grainSizeX': 50}, {'@type': 'PropertyValue', 'name': 'Target Grain Size y', 'value': 200, 'grainSizeY': 200}, {'@type': 'PropertyValue', 'name': 'Synthetic Composition', 'parameterControlled': [{'@type': 'Pr
# ...

# %%
for i,json_file in enumerate(json_files):
    png_file = json_file.replace('.json','.png')
    tiff_file = json_file.replace('.json','.tiff')
    with open(json_file) as f:
        obj = json.load(f)
    
    payloads = {
        'thumbnail': (png_file, open(png_file,'rb')),
        'image': (tiff_file, open(tiff_file,'rb'))
    }
    
    my_acl = dict()
    my_acl['readers'] = ['public']
    my_acl['writers'] = ['test/b1187cc0b52c9f37e17b']
    
    response = cordrapy.Objects.create(
        host,
        obj,
        obj_type,
        handle=obj['@id'],
        token=token,
        verify=False,
        acls=my_acl,
        payloads=payloads
    )
    print(i, response)
    
    #break
# Out:
# 0 {'@context': ['http://schema.org/', {'mat': 'https://pages.nist.gov/material-schema/', 'parameterControlled': 'mat:parameterControlled'}], '@type': ['Dataset', 'mat:File'], '@id': 'test/6859965e-bcec-4838-818b-1cbfb9df6952', 'name': 'PyMKS synthetic microstructure gx-50_gy-200_va-0.2_vb-0.2', 'about': ['test/36b943eb21e64e308b75'], 'accountablePerson': ['test/7c9446eb5abf408d3d0e'], 'author': ['test/00353486eaab904d29e1', 'test/7c9446eb5abf408d3d0e'], 'license': 'https://creativecommons.org/publicdomain/zero/1.0/', 'thumbnailUrl': ['https://api.materialhub.org/objects/test/6859965e-bcec-4838-818b-1cbfb9df6952?payload=thumbnail'], 'measurementTechnique': ['test/026f90694d58ac2eee70'], 'parameterControlled': [{'@type': 'PropertyValue', 'name': 'Target Grain Size x', 'value': 50, 'grainSizeX': 50}, {'@type': 'PropertyValue', 'name': 'Target Grain Size y', 'value': 200, 'grainSizeY': 200}, {'@type': 'PropertyValue', 'name': 'Synthetic Composition', 'parameterControlled': [{'@type': 'Pr
# ...

# %%
response = {'@context': ['http://schema.org/', {'mat': 'https://pages.nist.gov/material-schema/', 'parameterControlled': 'mat:parameterControlled'}], '@type': ['Dataset', 'mat:File'], '@id': 'test/6859965e-bcec-4838-818b-1cbfb9df6952', 'name': 'PyMKS synthetic microstructure gx-50_gy-200_va-0.2_vb-0.2', 'about': ['test/36b943eb21e64e308b75'], 'accountablePerson': ['test/7c9446eb5abf408d3d0e'], 'author': ['test/00353486eaab904d29e1', 'test/7c9446eb5abf408d3d0e'], 'license': 'https://creativecommons.org/publicdomain/zero/1.0/', 'thumbnailUrl': ['https://api.materialhub.org/objects/test/6859965e-bcec-4838-818b-1cbfb9df6952?payload=thumbnail'], 'measurementTechnique': ['test/026f90694d58ac2eee70'], 'parameterControlled': [{'@type': 'PropertyValue', 'name': 'Target Grain Size x', 'value': 50, 'grainSizeX': 50}, {'@type': 'PropertyValue', 'name': 'Target Grain Size y', 'value': 200, 'grainSizeY': 200}, {'@type': 'PropertyValue', 'name': 'Synthetic Composition', 'parameterControlled': [{'@type': 'PropertyValue', 'name': 'A', 'value': 0.2, 'unitText': 'Volume Fraction'}, {'@type': 'PropertyValue', 'name': 'B', 'value': 0.8, 'unitText': 'Volume Fraction'}], 'compositionSynthetic': {'volumeFraction': {'A': 0.2, 'B': 0.2}}}], 'distribution': {'contentUrl': 'https://api.materialhub.org/objects/test/6859965e-bcec-4838-818b-1cbfb9df6952?payload=image', 'encodingFormat': 'test/602049d594589158f8bf', 'type': 'DataDownload'}, 'isPartOf': ['test/dataset.2020.1']}

# %%
import json

print(json.dumps(response, indent=2))
# Out:
# {
#   "@context": [
#     "http://schema.org/",
#     {
#       "mat": "https://pages.nist.gov/material-schema/",
#       "parameterControlled": "mat:parameterControlled"
#     }
#   ],
#   "@type": [
#     "Dataset",
#     "mat:File"
#   ],
#   "@id": "test/6859965e-bcec-4838-818b-1cbfb9df6952",
#   "name": "PyMKS synthetic microstructure gx-50_gy-200_va-0.2_vb-0.2",
#   "about": [
#     "test/36b943eb21e64e308b75"
#   ],
#   "accountablePerson": [
#     "test/7c9446eb5abf408d3d0e"
#   ],
#   "author": [
#     "test/00353486eaab904d29e1",
#     "test/7c9446eb5abf408d3d0e"
#   ],
#   "license": "https://creativecommons.org/publicdomain/zero/1.0/",
#   "thumbnailUrl": [
#     "https://api.materialhub.org/objects/test/6859965e-bcec-4838-818b-1cbfb9df6952?payload=thumbnail"
#   ],
#   "measurementTechnique": [
#     "test/026f90694d58ac2eee70"
#   ],
#   "parameterControlled": [
#     {
#       "@type": "PropertyValue",
#       "name": "Target Grain Size x",
#       "value": 50,
# ...

# %%
import requests

params = dict()
params['type'] = 'File'
data = {
    "id" : "",
    "name" : "A different file",
    "@context": "",
    "@type": "",
    "@id": ""
}

r = requests.post(
    'https://api.materialhub.org/objects/?type=File',
    params=params,
    data=json.dumps(data),
    headers={
        'Authorization': 'Bearer ' + token['access_token'],
        'Content-Type': 'application/json'
    },
    verify=False
)

r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'@context': ['http://schema.org/',
#   {'mat': 'https://pages.nist.gov/material-schema/',
#    'parameterControlled': 'mat:parameterControlled'}],
#  '@type': ['Dataset', 'mat:File'],
#  '@id': 'test/23bdf2a62a83225a1b77',
#  'name': 'A different file',
#  'id': ''}

# %%
r = requests.get(
    'https://api.materialhub.org/objects/'+r.json()['@id'],
    headers={
        'Authorization': 'Bearer ' + token['access_token'],
        'Content-Type': 'application/json'
    },
    verify=False
)

r.json()
# Out:
# {'@context': ['http://schema.org/',
#   {'mat': 'https://pages.nist.gov/material-schema/',
#    'parameterControlled': 'mat:parameterControlled'}],
#  '@type': ['Dataset', 'mat:File'],
#  '@id': 'test/23bdf2a62a83225a1b77',
#  'name': 'A different file',
#  'id': '',
#  'metadata': {'createdOn': 1601660645165,
#   'createdBy': 'test/98e182d04a2a56bdd28a',
#   'modifiedOn': 1601660645165,
#   'modifiedBy': 'test/98e182d04a2a56bdd28a',
#   'txnId': 1601660645166006}}

# %%
data = {
    "id" : "",
    "name" : "A different file"
    "@context": "",
    "@type": "",
    "@id": ""
}
